# %%
print("                      WELCOME TO EXPERT SYSTEM          ")
print("              -------------------------------------")
print("            THIS EXPERT SYSTEM IS USED TO ORGANIZE CONFERENCES        ")
print("         ------------------------------------------------------------------")
a=[]
d=[]
print("DECIDE ON THEME")
print("1.TELECOMMUNICATIONS")
print("2.AUTOMOBILES")
print("Select a topic for conference")
n1=int(input())
if n1==1:
    print("enter the expected number of guests for telecommunications")
    n2=int(input())
    print("Your BUDGET for Organizing Conferenece")
    n4=int(input())
    u=0
    sponsors={
        "TELENOR":"10000-25000",
        "MOBILINK":"25001-50000",
        "UFONE":"50001-70000",
        "AIRTEL":"70001-100000",
        "RELIANCE":"100000-1000000"
        }
    for x in sponsors:
        r,l=sponsors[x].split("-")
        r=int(r)
        l=int(l)
        if n4>=r and n4<=l:
            u=1
            print("This company is ready to sponsor your conference")
            print(x)
            print("are you interested (Y/N)")
            z=input()
            if z=='N':
                print(" OH! ITS GREAT YOU ARE A SELF SPONSOR")
                x="self"
                break;
            else:
                print("OK! COMPANY IS READY TO SPONSOR YOUR CONFERENCE")
                break;
        
    if u==0:
        print("Sorry! No company is ready to sponser for your budget.")
        x="self"
            
    print("enter the no.of days to organize this conference")
    n5=int(input())
    print("choose your venue")
    if(n2<=100):
        print("1.SUBHAM CONVENTIONS-cost per day-5k")
        print("2.SIDDHARTHA GARDENS-cost per day-10k")
    elif(n2<=500):
        print("3.BANDLAMUDI GARDENS-cost per day-10k")
        print("4.LIONS CLUB,GUNTUR-cost per day-15k")
    elif(n2<=1000):
        print("5.THE VENUE-cost per day-20k")
        print("6.VEDIKA CONVENTION-cost per day-25k")
    f=int(input())
    print("choose the catering")
    print("1.ANNAPURNA CATERINGS-per head rs.75")
    print("2.RAMU CATERINGS-per head rs-100")
    print("3.SAGAR CATERINGS-per head rs-150")
    print("4.AMMA CATERINGS-per head rs-110")
    print("5.CHARAN CATERINGS-per head rs-90")
    p=int(input())
    print("----------------------------------------------")
    print(" YOUR THEME IS TELECOMMUNICATIONS")
    print("Number of expected guests ",n2)
    print("BUDGET IS ",n4)
    print("YOUR SPONSOR IS ",x)
    if(f==1):
        print("VENUE FOR CONFERENCE IS SUBHAM CONVENTIONS-for booking contact 9876543210")
    elif(f==2):
         print("VENUE FOR CONFERENCE IS SIDDHARTHA GARDENS-for booking contact 9876543210")
    elif(f==3):
         print("VENUE FOR CONFERENCE IS BANDLAMUDI GARDENS-for booking contact 9876543210")
    elif(f==4):
         print("VENUE FOR CONFERENCE IS LIONS CLUB,GUNTUR-for booking contact 9876543210")
    elif(f==5):
         print("VENUE FOR CONFERENCE IS THE VENUE FUNCTION HALL-for booking contact 9876543210")
    elif(f==6):
         print("VENUE FOR CONFERENCE IS VEDIKA CONVENTION-for booking contact 9876543210")
    else:
        print("SORRY! No venue available for your requirement")
    if(p==1):
        print("Your preferred catering is ANNAPURNA CATERINGS-for booking contact 6876543210")
    elif(p==2):
        print("Your preferred catering is RAMU CATERINGS-for booking contact 6876543210")
    elif(p==3):
        print("Your preferred catering is SAGAR CATERINGS-for booking contact 6876543210")
    elif(p==4):
        print("Your preferred catering is AMMA CATERINGS-for booking contact 6876543210")
    elif(p==5):
        print("Your preferred catering is CHARAN CATERINGS-for booking contact 6876543210")  
    else:
        print("NO CATERING found for your requirement")
elif n1==2:
    #print("ASSEMBLE YOUR TEAM")
    print("enter the expected number of guests for automobiles")
    n2=int(input())
    print("Your BUDGET for Organizing Conferenece")
    n4=int(input())
    u=0
    sponsors={
        "TATA MOTORS":"10000-25000",
        "MAHINDRA":"25000-50000",
        "TOYOTA":"50001-70000",
        "HONDA":"70001-100000"
        }
    for x in sponsors:
        r,l=sponsors[x].split("-")
        r=int(r)
        l=int(l)
        if n4>=r and n4<=l:
            u=1
            print("The company is ready to sponsor your conference")
            print(x)
            print("are you interested (Y/N)")
            z=input()
            if z=='N':
                print("OH! ITS GREAT YOU ARE A SELF SPONSOR")
                x="self"
                break;
            else:
                print("OK! COMPANY IS READY TO SPONSOR YOUE CONFERENCE")
                break;
    if u==0:
        print("Sorry! No company is ready to sponser for your budget.") 
        x="self"
    print("enter the no.of days to organize this conference")
    n5=int(input())
    print("choose your venue")
    if(n2<=100):
        print("1.SUBHAM CONVENTIONS-cost per day-5k")
        print("2.SIDDHARTHA GARDENS-cost per day-10k")
    elif(n2<=500):
        print("3.BANDLAMUDI GARDENS-cost per day-10k")
        print("4.LIONS CLUB,GUNTUR-cost per day-15k")
    elif(n2<=1000):
        print("5.THE VENUE-cost per day-20k")
        print("6.VEDIKA CONVENTION-cost per day-25k")
    f=int(input())
    print("choose the catering")
    print("1.ANNAPURNA CATERINGS-per head rs.75")
    print("2.RAMU CATERINGS-per head rs-100")
    print("3.SAGAR CATERINGS-per head rs-150")
    print("4.AMMA CATERINGS-per head rs-110")
    print("5.CHARAN CATERINGS-per head rs-90")
    p=int(input())
    print("----------------------------------------------")
    print(" YOUR THEME IS TELECOMMUNICATIONS")
    print("YOUR TEAM ",n2)
    #print(a)
    print("BUDGET IS ",n4)
    #print(n4)
    print("YOUR SPONSOR IS ",x)
    #print(x)
    if(f==1):
        print("VENUE FOR CONFERENCE IS SUBHAM CONVENTIONS-for booking contact 9876543210")
    elif(f==2):
         print("VENUE FOR CONFERENCE IS SIDDHARTHA GARDENS-for booking contact 9876543210")
    elif(f==3):
         print("VENUE FOR CONFERENCE IS BANDLAMUDI GARDENS-for booking contact 9876543210")
    elif(f==4):
         print("VENUE FOR CONFERENCE IS LIONS CLUB,GUNTUR-for booking contact 9876543210")
    elif(f==5):
         print("VENUE FOR CONFERENCE IS THE VENUE FUNCTION HALL-for booking contact 9876543210")
    elif(f==6):
         print("VENUE FOR CONFERENCE IS VEDIKA CONVENTION-for booking contact 9876543210")
    else:
        print("SORRY! No venue available for your requirement")
    if(p==1):
        print("Your preferred catering is ANNAPURNA CATERINGS-for booking contact 6876543210")
    elif(p==2):
        print("Your preferred catering is RAMU CATERINGS-for booking contact 6876543210")
    elif(p==3):
        print("Your preferred catering is SAGAR CATERINGS-for booking contact 6876543210")
    elif(p==4):
        print("Your preferred catering is AMMA CATERINGS-for booking contact 6876543210")
    elif(p==5):
        print("Your preferred catering is CHARAN CATERINGS-for booking contact 6876543210")  
    else:
        print("NO CATERING found for your requirement")
# Out:
#                       WELCOME TO EXPERT SYSTEM
#               -------------------------------------
#             THIS EXPERT SYSTEM IS USED TO ORGANIZE CONFERENCES
#          ------------------------------------------------------------------
# DECIDE ON THEME
# 1.TELECOMMUNICATIONS
# 2.AUTOMOBILES
# Select a topic for conference
# 1
# enter the expected number of guests for telecommunications
# 356
# Your BUDGET for Organizing Conferenece
# 23426
# This company is ready to sponsor your conference
# TELENOR
# are you interested (Y/N)
# N
#  OH! ITS GREAT YOU ARE A SELF SPONSOR
# enter the no.of days to organize this conference
# 2
# choose your venue
# 3.BANDLAMUDI GARDENS-cost per day-10k
# 4.LIONS CLUB,GUNTUR-cost per day-15k
# 3
# choose the catering
# 1.ANNAPURNA CATERINGS-per head rs.75
# 2.RAMU CATERINGS-per head rs-100
# 3.SAGAR CATERINGS-per head rs-150
# 4.AMMA CATERINGS-per head rs-110
# 5.CHARAN CATERINGS-per head rs-90
# 5
# ...
